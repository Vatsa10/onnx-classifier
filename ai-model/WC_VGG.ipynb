# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
import keras.layers as tkl
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("feyzazkefe/trashnet")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/feyzazkefe/trashnet?dataset_version_number=1...
# 100%|██████████| 40.8M/40.8M [00:00<00:00, 132MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/feyzazkefe/trashnet/versions/1

# %%
# Load your dataset and split it into training and validation sets
data_dir = '/root/.cache/kagglehub/datasets/feyzazkefe/trashnet/versions/1/dataset-resized'
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  label_mode='int',
  subset="training",
  seed = 1227,
  image_size=(224, 224),
  batch_size=32)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
valid_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  label_mode='int',
  subset="validation",
  seed = 1227,
  image_size=(224, 224),
  batch_size=32)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
num_classes = len(class_names)
print(num_classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# 6

# %%
val_batches = tf.data.experimental.cardinality(valid_ds)

# %%
val_batches = tf.data.experimental.cardinality(valid_ds)
test_ds = valid_ds.take(val_batches // 5)
valid_ds = valid_ds.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(valid_ds))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_ds))

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
valid_ds = valid_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Number of validation batches: 13
# Number of test batches: 3

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
valid_ds = valid_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# Use data augmentation to add more data for training
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
# Choose a pre-trained model to use as the basis for transfer learning
base_model = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.trainable = False
inputs = tf.keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

# %%
model = tf.keras.Model(inputs, outputs)

base_learning_rate = 0.001
# Compile the model with a loss function and an optimizer
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
initial_epochs = 80

# %%
callbacks_list = [ModelCheckpoint(filepath='model.keras', monitor='val_accuracy',
                                   verbose=1, save_best_only=True, save_weights_only=False, mode='max')]
csv_logger = CSVLogger('modeltraining.log', separator=',', append=False)

# Train the model on the training set
history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=(valid_ds),
                    callbacks=(callbacks_list+[csv_logger]))
# Out:
# Epoch 1/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4642 - loss: 13.8425
# Epoch 1: val_accuracy improved from -inf to 0.72372, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.4656 - loss: 13.8215 - val_accuracy: 0.7237 - val_loss: 9.7681
# Epoch 2/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7462 - loss: 8.8736
# Epoch 2: val_accuracy improved from 0.72372 to 0.74328, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.7460 - loss: 8.8613 - val_accuracy: 0.7433 - val_loss: 6.4396
# Epoch 3/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7466 - loss: 5.8793
# Epoch 3: val_accuracy improved from 0.74328 to 0.79707, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.7468 - loss: 5.8710 - val_accuracy: 0.7971 - val_loss: 4.2310
# Epoch 4/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7826 - loss: 3.9235
# Epoch 4: val_accuracy improved from 0.79707 to 0.80685, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.7826 - loss: 3.9188 - val_accuracy: 0.8068 - val_loss: 2.9438
# Epoch 5/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7805 - loss: 2.7782
# Epoch 5: val_accuracy did not improve from 0.80685
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 178ms/step - accuracy: 0.7807 - loss: 2.7753 - val_accuracy: 0.8068 - val_loss: 2.2309
# Epoch 6/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8129 - loss: 2.0707
# Epoch 6: val_accuracy improved from 0.80685 to 0.82885, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - accuracy: 0.8128 - loss: 2.0695 - val_accuracy: 0.8289 - val_loss: 1.7577
# Epoch 7/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8203 - loss: 1.6517
# Epoch 7: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8202 - loss: 1.6512 - val_accuracy: 0.8020 - val_loss: 1.5937
# Epoch 8/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8233 - loss: 1.4362
# Epoch 8: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 185ms/step - accuracy: 0.8230 - loss: 1.4362 - val_accuracy: 0.8093 - val_loss: 1.3888
# Epoch 9/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8061 - loss: 1.3750
# Epoch 9: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8060 - loss: 1.3751 - val_accuracy: 0.8044 - val_loss: 1.3453
# Epoch 10/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8064 - loss: 1.3329
# Epoch 10: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8065 - loss: 1.3326 - val_accuracy: 0.7971 - val_loss: 1.3518
# Epoch 11/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8005 - loss: 1.2620
# Epoch 11: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.8006 - loss: 1.2614 - val_accuracy: 0.8166 - val_loss: 1.2327
# Epoch 12/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8462 - loss: 1.1584
# Epoch 12: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.8460 - loss: 1.1585 - val_accuracy: 0.8068 - val_loss: 1.1873
# Epoch 13/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8042 - loss: 1.1826
# Epoch 13: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.8043 - loss: 1.1825 - val_accuracy: 0.8068 - val_loss: 1.1811
# Epoch 14/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8087 - loss: 1.1720
# Epoch 14: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8087 - loss: 1.1721 - val_accuracy: 0.8264 - val_loss: 1.1872
# Epoch 15/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8004 - loss: 1.2077
# Epoch 15: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8006 - loss: 1.2073 - val_accuracy: 0.8093 - val_loss: 1.1906
# Epoch 16/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8030 - loss: 1.1781
# Epoch 16: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.8030 - loss: 1.1782 - val_accuracy: 0.8264 - val_loss: 1.1517
# Epoch 17/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8280 - loss: 1.1326
# Epoch 17: val_accuracy improved from 0.82885 to 0.83130, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.8279 - loss: 1.1325 - val_accuracy: 0.8313 - val_loss: 1.0919
# Epoch 18/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8321 - loss: 1.1504
# Epoch 18: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - accuracy: 0.8321 - loss: 1.1501 - val_accuracy: 0.8289 - val_loss: 1.1095
# Epoch 19/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8133 - loss: 1.1357
# Epoch 19: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8131 - loss: 1.1361 - val_accuracy: 0.8044 - val_loss: 1.2445
# Epoch 20/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7894 - loss: 1.2210
# Epoch 20: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.7898 - loss: 1.2203 - val_accuracy: 0.8068 - val_loss: 1.1903
# Epoch 21/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8108 - loss: 1.1512
# Epoch 21: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8109 - loss: 1.1507 - val_accuracy: 0.8264 - val_loss: 1.1291
# Epoch 22/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8129 - loss: 1.1270
# Epoch 22: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - accuracy: 0.8129 - loss: 1.1270 - val_accuracy: 0.8215 - val_loss: 1.1609
# Epoch 23/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8244 - loss: 1.1019
# Epoch 23: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - accuracy: 0.8245 - loss: 1.1019 - val_accuracy: 0.8142 - val_loss: 1.1727
# Epoch 24/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8297 - loss: 1.1057
# Epoch 24: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.8297 - loss: 1.1056 - val_accuracy: 0.8313 - val_loss: 1.1891
# Epoch 25/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8268 - loss: 1.0935
# Epoch 25: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.8267 - loss: 1.0937 - val_accuracy: 0.7946 - val_loss: 1.2048
# Epoch 26/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8057 - loss: 1.1489
# Epoch 26: val_accuracy did not improve from 0.83130
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 185ms/step - accuracy: 0.8058 - loss: 1.1493 - val_accuracy: 0.8215 - val_loss: 1.1392
# Epoch 27/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8081 - loss: 1.1814
# Epoch 27: val_accuracy improved from 0.83130 to 0.83619, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.8081 - loss: 1.1816 - val_accuracy: 0.8362 - val_loss: 1.1527
# Epoch 28/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8409 - loss: 1.0681
# Epoch 28: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 188ms/step - accuracy: 0.8408 - loss: 1.0680 - val_accuracy: 0.8191 - val_loss: 1.0859
# Epoch 29/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8243 - loss: 1.1012
# Epoch 29: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.8242 - loss: 1.1012 - val_accuracy: 0.8093 - val_loss: 1.1353
# Epoch 30/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8181 - loss: 1.0976
# Epoch 30: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8181 - loss: 1.0975 - val_accuracy: 0.8166 - val_loss: 1.1057
# Epoch 31/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8469 - loss: 1.0081
# Epoch 31: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - accuracy: 0.8467 - loss: 1.0086 - val_accuracy: 0.7946 - val_loss: 1.1477
# Epoch 32/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8409 - loss: 1.0499
# Epoch 32: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 186ms/step - accuracy: 0.8408 - loss: 1.0500 - val_accuracy: 0.8117 - val_loss: 1.1363
# Epoch 33/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8304 - loss: 1.0436
# Epoch 33: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.8306 - loss: 1.0432 - val_accuracy: 0.8093 - val_loss: 1.1255
# Epoch 34/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8360 - loss: 1.0392
# Epoch 34: val_accuracy did not improve from 0.83619
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8359 - loss: 1.0394 - val_accuracy: 0.8044 - val_loss: 1.1571
# Epoch 35/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8280 - loss: 1.0794
# Epoch 35: val_accuracy improved from 0.83619 to 0.84108, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.8280 - loss: 1.0795 - val_accuracy: 0.8411 - val_loss: 1.0703
# Epoch 36/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8399 - loss: 1.0635
# Epoch 36: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8398 - loss: 1.0634 - val_accuracy: 0.8117 - val_loss: 1.1322
# Epoch 37/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8311 - loss: 1.1018
# Epoch 37: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8311 - loss: 1.1019 - val_accuracy: 0.8068 - val_loss: 1.1542
# Epoch 38/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8377 - loss: 1.0938
# Epoch 38: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8378 - loss: 1.0935 - val_accuracy: 0.8166 - val_loss: 1.0993
# Epoch 39/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8168 - loss: 1.0821
# Epoch 39: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8170 - loss: 1.0817 - val_accuracy: 0.8142 - val_loss: 1.0920
# Epoch 40/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8340 - loss: 1.0102
# Epoch 40: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8341 - loss: 1.0102 - val_accuracy: 0.8313 - val_loss: 1.0731
# Epoch 41/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8161 - loss: 1.0565
# Epoch 41: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8162 - loss: 1.0563 - val_accuracy: 0.8289 - val_loss: 1.0443
# Epoch 42/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8294 - loss: 1.0261
# Epoch 42: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8294 - loss: 1.0263 - val_accuracy: 0.8215 - val_loss: 1.0517
# Epoch 43/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8406 - loss: 1.0179
# Epoch 43: val_accuracy did not improve from 0.84108
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8406 - loss: 1.0180 - val_accuracy: 0.8093 - val_loss: 1.1142
# Epoch 44/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8133 - loss: 1.0309
# Epoch 44: val_accuracy improved from 0.84108 to 0.84352, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - accuracy: 0.8134 - loss: 1.0311 - val_accuracy: 0.8435 - val_loss: 1.0364
# Epoch 45/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8276 - loss: 1.0209
# Epoch 45: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8277 - loss: 1.0207 - val_accuracy: 0.8264 - val_loss: 1.0360
# Epoch 46/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8345 - loss: 1.0112
# Epoch 46: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8345 - loss: 1.0112 - val_accuracy: 0.8166 - val_loss: 1.0596
# Epoch 47/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8499 - loss: 0.9757
# Epoch 47: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8498 - loss: 0.9757 - val_accuracy: 0.8215 - val_loss: 1.0161
# Epoch 48/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8422 - loss: 0.9954
# Epoch 48: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8420 - loss: 0.9959 - val_accuracy: 0.8215 - val_loss: 1.0512
# Epoch 49/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8527 - loss: 0.9834
# Epoch 49: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8525 - loss: 0.9840 - val_accuracy: 0.8166 - val_loss: 1.0946
# Epoch 50/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8340 - loss: 1.0007
# Epoch 50: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8340 - loss: 1.0006 - val_accuracy: 0.8240 - val_loss: 1.0391
# Epoch 51/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8294 - loss: 1.0281
# Epoch 51: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8296 - loss: 1.0281 - val_accuracy: 0.8240 - val_loss: 1.0311
# Epoch 52/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8554 - loss: 0.9601
# Epoch 52: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8554 - loss: 0.9600 - val_accuracy: 0.8289 - val_loss: 1.0139
# Epoch 53/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8396 - loss: 0.9844
# Epoch 53: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.8395 - loss: 0.9848 - val_accuracy: 0.8362 - val_loss: 0.9999
# Epoch 54/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8324 - loss: 0.9980
# Epoch 54: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8325 - loss: 0.9979 - val_accuracy: 0.8264 - val_loss: 1.0280
# Epoch 55/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8531 - loss: 0.9590
# Epoch 55: val_accuracy did not improve from 0.84352
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8531 - loss: 0.9591 - val_accuracy: 0.8289 - val_loss: 1.0252
# Epoch 56/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8351 - loss: 1.0159
# Epoch 56: val_accuracy improved from 0.84352 to 0.84841, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.8352 - loss: 1.0158 - val_accuracy: 0.8484 - val_loss: 1.0737
# Epoch 57/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8412 - loss: 1.0046
# Epoch 57: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.8410 - loss: 1.0052 - val_accuracy: 0.8240 - val_loss: 1.0994
# Epoch 58/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8348 - loss: 1.0095
# Epoch 58: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8349 - loss: 1.0095 - val_accuracy: 0.8289 - val_loss: 1.1235
# Epoch 59/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8453 - loss: 1.0288
# Epoch 59: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 185ms/step - accuracy: 0.8454 - loss: 1.0287 - val_accuracy: 0.8264 - val_loss: 1.0260
# Epoch 60/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8534 - loss: 0.9812
# Epoch 60: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.8534 - loss: 0.9813 - val_accuracy: 0.8264 - val_loss: 1.0635
# Epoch 61/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8306 - loss: 1.0024
# Epoch 61: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.8309 - loss: 1.0018 - val_accuracy: 0.8191 - val_loss: 1.0500
# Epoch 62/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8499 - loss: 0.9635
# Epoch 62: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.8499 - loss: 0.9635 - val_accuracy: 0.8484 - val_loss: 0.9495
# Epoch 63/80
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8498 - loss: 0.9769
# Epoch 63: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0
# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,10.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  22

# %%
for layer in base_model.layers:
    layer.trainable = True

# %%
base_model.trainable = True
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,079,622 (80.41 MB)
#  Trainable params: 21,078,598 (80.41 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
total_epochs=160

# %%
# Fine-tune the model on the training set
history_fine = model.fit(train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=valid_ds,
                         callbacks=(callbacks_list+[csv_logger]))
# Out:
# Epoch 80/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.6177 - loss: 1.6143
# Epoch 80: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 48s 561ms/step - accuracy: 0.6177 - loss: 1.6139 - val_accuracy: 0.5134 - val_loss: 2.0892
# Epoch 81/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.6702 - loss: 1.3893
# Epoch 81: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 526ms/step - accuracy: 0.6700 - loss: 1.3898 - val_accuracy: 0.5159 - val_loss: 2.3015
# Epoch 82/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7342 - loss: 1.1836
# Epoch 82: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 524ms/step - accuracy: 0.7342 - loss: 1.1836 - val_accuracy: 0.6846 - val_loss: 1.4960
# Epoch 83/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7533 - loss: 1.1209
# Epoch 83: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 527ms/step - accuracy: 0.7533 - loss: 1.1209 - val_accuracy: 0.7433 - val_loss: 1.1027
# Epoch 84/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.8075 - loss: 0.9756
# Epoch 84: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 527ms/step - accuracy: 0.8077 - loss: 0.9751 - val_accuracy: 0.6112 - val_loss: 1.5188
# Epoch 85/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7959 - loss: 0.9902
# Epoch 85: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 525ms/step - accuracy: 0.7963 - loss: 0.9891 - val_accuracy: 0.7775 - val_loss: 0.9965
# Epoch 86/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.8513 - loss: 0.8141
# Epoch 86: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 525ms/step - accuracy: 0.8513 - loss: 0.8141 - val_accuracy: 0.7188 - val_loss: 1.2347
# Epoch 87/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.8555 - loss: 0.8095
# Epoch 87: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 525ms/step - accuracy: 0.8555 - loss: 0.8094 - val_accuracy: 0.7995 - val_loss: 0.9891
# Epoch 88/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.8664 - loss: 0.7507
# Epoch 88: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 526ms/step - accuracy: 0.8664 - loss: 0.7505 - val_accuracy: 0.7726 - val_loss: 0.9700
# Epoch 89/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.8710 - loss: 0.7101
# Epoch 89: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 527ms/step - accuracy: 0.8710 - loss: 0.7100 - val_accuracy: 0.7042 - val_loss: 1.2902
# Epoch 90/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.8691 - loss: 0.7338
# Epoch 90: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 524ms/step - accuracy: 0.8691 - loss: 0.7336 - val_accuracy: 0.7384 - val_loss: 1.2211
# Epoch 91/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.8882 - loss: 0.6383
# Epoch 91: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s 525ms/step - accuracy: 0.8882 - loss: 0.6382 - val_accuracy: 0.8460 - val_loss: 0.8222
# Epoch 92/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9142 - loss: 0.5821
# Epoch 92: val_accuracy did not improve from 0.85575
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 34s
160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9557 - loss: 0.2319
# Epoch 159: val_accuracy did not improve from 0.93643
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.9557 - loss: 0.2315 - val_accuracy: 0.8191 - val_loss: 0.8860
# Epoch 160/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9753 - loss: 0.1645
# Epoch 160: val_accuracy did not improve from 0.93643
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 33s 520ms/step - accuracy: 0.9753 - loss: 0.1643 - val_accuracy: 0.8998 - val_loss: 0.4144

# %%
train_loss, train_acc = model.evaluate(train_ds)
print('Train accuracy: {}'.format(train_acc))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9739 - loss: 0.1539
# Train accuracy: 0.9807121753692627

# %%
val_loss, val_acc = model.evaluate(valid_ds)
print('Validation accuracy: {}'.format(val_acc))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.8811 - loss: 0.5000
# Validation accuracy: 0.8875305652618408

# %%
test_loss, test_acc = model.evaluate(test_ds)
print('Test accuracy: {}'.format(test_acc))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9336 - loss: 0.3076
# Test accuracy: 0.90625

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
image_batch, label_batch = test_ds.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

plt.figure(figsize=(12, 12))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].astype("uint8"))
    actual_label = class_names[label_batch[i]]
    predicted_label = class_names[np.argmax(predictions[i])]
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis("off")

# Adjust the space between the plots
plt.subplots_adjust(wspace=1, hspace=0.5)

plt.show()

# %%
image_batch, label_batch = test_ds.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

plt.figure(figsize=(12, 12))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].astype("uint8"))
    actual_label = class_names[label_batch[i]]
    predicted_label = class_names[np.argmax(predictions[i])]
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis("off")

# Adjust the space between the plots
plt.subplots_adjust(wspace=1, hspace=0.5)

plt.show()

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import matplotlib.pyplot as plt

# Load the image
img = image.load_img('/root/.cache/kagglehub/datasets/feyzazkefe/trashnet/versions/1/dataset-resized/glass/glass1.jpg', target_size=(224, 224))

# Convert the image to a numpy array
img_array = image.img_to_array(img)

# Expand dimensions to match the shape that the model expects
img_array_expanded = np.expand_dims(img_array, axis=0)

# Preprocess the image using the same preprocessing function you used during training
img_array_preprocessed = preprocess_input(img_array_expanded)

# Make a prediction
predictions = model.predict(img_array_preprocessed)

# Get the predicted class
predicted_class = class_names[np.argmax(predictions[0])]

# Display the image along with the predicted class
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step

# %%
model.save('waste_classification_model-vgg19.keras')
